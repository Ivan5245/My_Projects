# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivan5245/My_Projects/blob/main/%D0%94%D0%971.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,3,4,5]
k=2

n=len(a)
if(n%k==0):
  q=n//k
  k1=k
else:
  q=n
  k1=1

for i1 in range(k1):
  next=i1
  prev=a[i1]
  for _ in range(q):
    next=(next+k)%n
    cur=a[next]
    a[next]=prev
    prev=cur


print(a)
# Out:
# [4, 5, 1, 2, 3]

# %%
вавав

# %% [markdown]
# Данное решение использует линейное время, так как состоит из двойного цикла for, где произведение пределов итерирования равно n. Выделяемая память константна, так как не происходит выделения массивов.
